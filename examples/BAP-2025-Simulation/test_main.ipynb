# %%
from illuminator.engine import Simulation
import nest_asyncio
nest_asyncio.apply()

# %%
simulation = Simulation('Dutch_grid.yaml')
# Out:
# C:\Users\krahi\Documents\Illuminator\Repo\Illuminator-BAP-EE-2025\examples\BAP-2025-Simulation

# %%
simulation.run()
# Out:
#         ____                              _ _
#        /    \                            (_) |
#   ____/      \  _ __ ___   ___  ___  __ _ _| | __
#  /    \      / | '_ ` _ \ / _ \/ __|/ _` | | |/ /
# /      \____/  | | | | | | (_) \__ \ (_| | |   <
# \      /    \  |_| |_| |_|\___/|___/\__,_|_|_|\_\
#  \____/      \____
#  /    \      /    \     mosaik: 3.5.0
# /      \____/      \       API: 3.0.13
# \      /    \      /    Python: 3.11.9
#  \____/      \____/         OS: Windows-10-10.0.26100-SP0
#       \      /            Docs: https://mosaik.readthedocs.io/en/3.5.0/
#        \____/     Get in touch: https://github.com/orgs/OFFIS-mosaik/discussions
#
# 2025-06-16 09:37:41.542 | INFO     | mosaik.async_scenario:start:420 - Starting "Collector" as "Collector-0" ...
# 2025-06-16 09:37:42.148 | INFO     | mosaik.async_scenario:start:420 - Starting "Pandacontroller1" as "Pandacontroller1-0" ...
# ...
# check
# check
# check
# check
# check
# check
# check
# check
# check
# check
# check
# ...
