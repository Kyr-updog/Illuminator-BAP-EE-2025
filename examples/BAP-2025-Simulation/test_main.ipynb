# %%
import pandas as pd

df = pd.read_csv('line_specs.csv')

df
# Out:
#    line_id  reactance  capacity
# 0        1         10       100
# 1        2         20       200
# 2        3         30       300
# 3        4         40       400
# 4        5         50       500
