# %% [markdown]
# # Practical Power Balancing for a Local Community

# %% [markdown]
# #### Importing the needed packages
# The first step in every python notebook is to install the needed packages (e.g. [`pandas`](https://pandas.pydata.org/docs/user_guide/index.html) for data management) as well as functions and classes from external scripts.

# %%
from illuminator.engine import Simulation
import functions_T1
import pandas as pd
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# In this tutorial a neighbourhood is connected to the grid as sketched below. For a typical day in the year the neighbourhood has a given demand profile (load_data.txt file). The given load data is for a year and is given in 15 minute intervals. This electricity demand must be fulfilled.

# %% [markdown]
# #### Task 1: Load Profile for a Neighbourhood
#
# In the first task entails the neighbourhood takes all electricity from the grid. The demand of the neighbourhood can be visualized in a load profile for a day of choice. The following python code plots a specified day based on the given load data and the specified number of houses in the neighbourhood. Electricity from the grid comes from various sources. The energy mix of the Netherlands can be found under https://www.iea.org/countries/the-netherlands/energy-mix. In the code the load data is first saved in a pandas dataframe and it is ensured that the index is the time. Then the day is chosen and a function is called to plot the load data on this day.
# <br> <br> Run the code and describe what you can see in the plot (certain regular peaks, irregularities, etc.). You can vary the day for which you want to plot the load with the day_of_year parameter. Here, you can also compare the load on different days.

# %% [markdown]
# ![T1_basecase](Graphics_T1/neighbourhood_base_case_T1.png)

# %%
load_df = pd.read_csv('data/load_data.txt', delimiter=',', skiprows=1)
load_df['time'] = pd.to_datetime(load_df['time'])
load_df.set_index('time', inplace=True)
#choose which day of the year to plot
day_of_year = "2012-06-01"
number_houses = 5 
plot_load_base_case = functions_T1.plot_load_profile(load_df, day_of_year, number_houses)

# %% [markdown]
# The community implements small scale PV and wind power plants to become more autonomous. Now first the supply from the local renewable energy sources is used to cover the demand in the community. The residual load is then supplied by the grid. In case of excess renewable generation the generated electricity is fed into the grid.

# %% [markdown]
# ![T1_RES_case](Graphics_T1/neighbourhood_RES_case_T1.png)

# %% [markdown]
# #### Task 2: Neighbourhood with local RES
#
# In the below presented code the neighbourhood is set up by defining the key components (here Wind, PV and Load). After defining number of houses and specifications of the installed wind and solar energy in the neighbourhood, a simulation is created and started with the simulation_creator_Balancing class. Finally, the summarise_results function creates a plot and an hourly table with the key results.
#
# Run the following python code and look at the resulting residual load plot. Describe the plot and compare it to the results from task 1. How did the load change for the different days you tested in task 1? Vary the installed PV and Wind power as well as the number of houses in the neighbourhood. Describe your findings.

# %%
# %%capture
CONFIG_FILE = 'Tutorial_Power_Balance_a.yaml'
simulation_RES = Simulation(CONFIG_FILE)
simulation_RES.set_model_param(model_name='CSVload', parameter='file_path', value='data/load_data.txt')
simulation_RES.set_model_param(model_name='CSV_pv', parameter='file_path', value='data/pv_data_Rotterdam_NL-15min.txt')
simulation_RES.set_model_param(model_name='CSV_wind', parameter='file_path', value='data/winddata_NL.txt')

new_settings = {'Wind1': {'p_rated': 0.3}, # power in kW
                'Load1': {'houses': 5}, # number of houses
                'PV1':{'cap': 500} # installed capacity in W
                }

simulation_RES.edit_models(new_settings)

simulation_RES.set_scenario_param('start_time', '2012-06-01 00:00:00')
simulation_RES.set_scenario_param('end_time', '2012-06-01 23:45:00')

# run the simulation
simulation_RES.run()
# Out:
# 2025-06-16 12:10:59.934 | INFO     | mosaik.async_scenario:start:420 - Starting "Collector" as "Collector-0" ...
# 2025-06-16 12:11:01.220 | INFO     | mosaik.async_scenario:start:420 - Starting "CSVload" as "CSVload-0" ...
# 2025-06-16 12:11:01.865 | WARNING  | mosaik.async_scenario:user_warning:342 - c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\site-packages\mosaik\adapters.py:98: UserWarning: Simulator CSVload-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-06-16 12:11:01.867 | INFO     | mosaik.async_scenario:start:420 - Starting "CSV_pv" as "CSV_pv-0" ...
# 2025-06-16 12:11:02.501 | WARNING  | mosaik.async_scenario:user_warning:342 - c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\site-packages\mosaik\adapters.py:98: UserWarning: Simulator CSV_pv-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-06-16 12:11:02.503 | INFO     | mosaik.async_scenario:start:420 - Starting "CSV_wind" as "CSV_wind-0" ...
# 2025-06-16 12:11:03.113 | WARNING  | mosaik.async_scenario:user_warning:342 - c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\site-packages\mosaik\adapters.py:98: UserWarning: Simulator CSV_wind-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-06-16 12:11:03.124 | INFO     | mosaik.async_scenario:start:420 - Starting "Load1" as "Load1-0" ...
# 2025-06-16 12:11:03.124 | WARNING  | mosaik.async_scenario:user_warning:342 - c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\site-packages\mosaik\adapters.py:98: UserWarning: Simulator Load1-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-06-16 12:11:03.124 | INFO     | mosaik.async_scenario:start:420 - Starting "PV1" as "PV1-0" ...
# 2025-06-16 12:11:03.124 | WARNING  | mosaik.async_scenario:user_warning:342 - c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\site-packages\mosaik\adapters.py:98: UserWarning: Simulator PV1-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-06-16 12:11:03.128 | INFO     | mosaik.async_scenario:start:420 - Starting "Wind1" as "Wind1-0" ...
# 2025-06-16 12:11:03.180 | WARNING  | mosaik.async_scenario:user_warning:342 - c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\site-packages\mosaik\adapters.py:98: UserWarning: Simulator Wind1-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-06-16 12:11:03.192 | INFO     | mosaik.async_scenario:start:420 - Starting "Controller1" as "Controller1-0" ...
# 2025-06-16 12:11:03.192 | WARNING  | mosaik.async_scenario:user_warning:342 - c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\site-packages\mosaik\adapters.py:98: UserWarning: Simulator Controller1-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-06-16 12:11:03.192 | INFO     | mosaik.async_scenario:run:789 - Starting simulation.
# 2025-06-16 12:11:06.244 | INFO     | mosaik.async_scenario:run:845 - Simulation finished successfully.

# %% [markdown]
# # Practical Power Balancing for a Local Community

# %% [markdown]
# #### Importing the needed packages
# The first step in every python notebook is to install the needed packages (e.g. [`pandas`](https://pandas.pydata.org/docs/user_guide/index.html) for data management) as well as functions and classes from external scripts.

# %%
from illuminator.engine import Simulation
import functions_T1
import pandas as pd
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# In this tutorial a neighbourhood is connected to the grid as sketched below. For a typical day in the year the neighbourhood has a given demand profile (load_data.txt file). The given load data is for a year and is given in 15 minute intervals. This electricity demand must be fulfilled.

# %% [markdown]
# #### Task 1: Load Profile for a Neighbourhood
#
# In the first task entails the neighbourhood takes all electricity from the grid. The demand of the neighbourhood can be visualized in a load profile for a day of choice. The following python code plots a specified day based on the given load data and the specified number of houses in the neighbourhood. Electricity from the grid comes from various sources. The energy mix of the Netherlands can be found under https://www.iea.org/countries/the-netherlands/energy-mix. In the code the load data is first saved in a pandas dataframe and it is ensured that the index is the time. Then the day is chosen and a function is called to plot the load data on this day.
# <br> <br> Run the code and describe what you can see in the plot (certain regular peaks, irregularities, etc.). You can vary the day for which you want to plot the load with the day_of_year parameter. Here, you can also compare the load on different days.

# %% [markdown]
# ![T1_basecase](Graphics_T1/neighbourhood_base_case_T1.png)

# %%
load_df = pd.read_csv('data/load_data.txt', delimiter=',', skiprows=1)
load_df['time'] = pd.to_datetime(load_df['time'])
load_df.set_index('time', inplace=True)
#choose which day of the year to plot
day_of_year = "2012-06-01"
number_houses = 5 
plot_load_base_case = functions_T1.plot_load_profile(load_df, day_of_year, number_houses)

# %% [markdown]
# The community implements small scale PV and wind power plants to become more autonomous. Now first the supply from the local renewable energy sources is used to cover the demand in the community. The residual load is then supplied by the grid. In case of excess renewable generation the generated electricity is fed into the grid.

# %% [markdown]
# ![T1_RES_case](Graphics_T1/neighbourhood_RES_case_T1.png)

# %% [markdown]
# #### Task 2: Neighbourhood with local RES
#
# In the below presented code the neighbourhood is set up by defining the key components (here Wind, PV and Load). After defining number of houses and specifications of the installed wind and solar energy in the neighbourhood, a simulation is created and started with the simulation_creator_Balancing class. Finally, the summarise_results function creates a plot and an hourly table with the key results.
#
# Run the following python code and look at the resulting residual load plot. Describe the plot and compare it to the results from task 1. How did the load change for the different days you tested in task 1? Vary the installed PV and Wind power as well as the number of houses in the neighbourhood. Describe your findings.

# %%
# %%capture
CONFIG_FILE = 'Tutorial_Power_Balance_a.yaml'
simulation_RES = Simulation(CONFIG_FILE)
simulation_RES.set_model_param(model_name='CSVload', parameter='file_path', value='data/load_data.txt')
simulation_RES.set_model_param(model_name='CSV_pv', parameter='file_path', value='data/pv_data_Rotterdam_NL-15min.txt')
simulation_RES.set_model_param(model_name='CSV_wind', parameter='file_path', value='data/winddata_NL.txt')

new_settings = {'Wind1': {'p_rated': 0.3}, # power in kW
                'Load1': {'houses': 5}, # number of houses
                'PV1':{'cap': 500} # installed capacity in W
                }

simulation_RES.edit_models(new_settings)

simulation_RES.set_scenario_param('start_time', '2012-06-01 00:00:00')
simulation_RES.set_scenario_param('end_time', '2012-06-01 23:45:00')

# run the simulation
simulation_RES.run()
# Out:
# 2025-06-16 12:11:06.658 | INFO     | mosaik.async_scenario:start:420 - Starting "Collector" as "Collector-0" ...
# 2025-06-16 12:11:08.007 | INFO     | mosaik.async_scenario:start:420 - Starting "CSVload" as "CSVload-0" ...
# 2025-06-16 12:11:08.637 | WARNING  | mosaik.async_scenario:user_warning:342 - c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\site-packages\mosaik\adapters.py:98: UserWarning: Simulator CSVload-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-06-16 12:11:08.637 | INFO     | mosaik.async_scenario:start:420 - Starting "CSV_pv" as "CSV_pv-0" ...
# 2025-06-16 12:11:09.193 | WARNING  | mosaik.async_scenario:user_warning:342 - c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\site-packages\mosaik\adapters.py:98: UserWarning: Simulator CSV_pv-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-06-16 12:11:09.209 | INFO     | mosaik.async_scenario:start:420 - Starting "CSV_wind" as "CSV_wind-0" ...
# 2025-06-16 12:11:09.853 | WARNING  | mosaik.async_scenario:user_warning:342 - c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\site-packages\mosaik\adapters.py:98: UserWarning: Simulator CSV_wind-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-06-16 12:11:09.856 | INFO     | mosaik.async_scenario:start:420 - Starting "Load1" as "Load1-0" ...
# 2025-06-16 12:11:09.856 | WARNING  | mosaik.async_scenario:user_warning:342 - c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\site-packages\mosaik\adapters.py:98: UserWarning: Simulator Load1-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-06-16 12:11:09.856 | INFO     | mosaik.async_scenario:start:420 - Starting "PV1" as "PV1-0" ...
# 2025-06-16 12:11:09.856 | WARNING  | mosaik.async_scenario:user_warning:342 - c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\site-packages\mosaik\adapters.py:98: UserWarning: Simulator PV1-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-06-16 12:11:09.856 | INFO     | mosaik.async_scenario:start:420 - Starting "Wind1" as "Wind1-0" ...
# 2025-06-16 12:11:09.861 | WARNING  | mosaik.async_scenario:user_warning:342 - c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\site-packages\mosaik\adapters.py:98: UserWarning: Simulator Wind1-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-06-16 12:11:09.863 | INFO     | mosaik.async_scenario:start:420 - Starting "Controller1" as "Controller1-0" ...
# 2025-06-16 12:11:09.863 | WARNING  | mosaik.async_scenario:user_warning:342 - c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\site-packages\mosaik\adapters.py:98: UserWarning: Simulator Controller1-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-06-16 12:11:09.863 | INFO     | mosaik.async_scenario:run:789 - Starting simulation.
# 2025-06-16 12:11:13.172 | INFO     | mosaik.async_scenario:run:845 - Simulation finished successfully.

# %%
functions_T1.summarize_results('./out_Tutorial_Power_Balance_a.csv', battery_active = False)
# Out:
# <style type="text/css">
# #T_ecdca_row0_col0, #T_ecdca_row0_col1, #T_ecdca_row0_col2, #T_ecdca_row0_col3, #T_ecdca_row0_col4, #T_ecdca_row0_col5, #T_ecdca_row1_col0, #T_ecdca_row1_col1, #T_ecdca_row1_col2, #T_ecdca_row1_col3, #T_ecdca_row1_col4, #T_ecdca_row1_col5, #T_ecdca_row2_col0, #T_ecdca_row2_col1, #T_ecdca_row2_col2, #T_ecdca_row2_col3, #T_ecdca_row2_col4, #T_ecdca_row2_col5, #T_ecdca_row3_col0, #T_ecdca_row3_col1, #T_ecdca_row3_col2, #T_ecdca_row3_col3, #T_ecdca_row3_col4, #T_ecdca_row3_col5, #T_ecdca_row4_col0, #T_ecdca_row4_col1, #T_ecdca_row4_col2, #T_ecdca_row4_col3, #T_ecdca_row4_col4, #T_ecdca_row4_col5, #T_ecdca_row5_col0, #T_ecdca_row5_col1, #T_ecdca_row5_col2, #T_ecdca_row5_col3, #T_ecdca_row5_col4, #T_ecdca_row5_col5, #T_ecdca_row6_col0, #T_ecdca_row6_col1, #T_ecdca_row6_col2, #T_ecdca_row6_col3, #T_ecdca_row6_col4, #T_ecdca_row6_col5, #T_ecdca_row7_col0, #T_ecdca_row7_col1, #T_ecdca_row7_col2, #T_ecdca_row7_col3, #T_ecdca_row7_col4, #T_ecdca_row7_col5, #T_ecdca_row8_col0, #T_ecdca_row8_col1, #T_ecdca_row8_col2, #T_ecdca_row8_col3, #T_ecdca_row8_col4, #T_ecdca_row8_col5, #T_ecdca_row9_col0, #T_ecdca_row9_col1, #T_ecdca_row9_col2, #T_ecdca_row9_col3, #T_ecdca_row9_col4, #T_ecdca_row9_col5, #T_ecdca_row10_col0, #T_ecdca_row10_col1, #T_ecdca_row10_col2, #T_ecdca_row10_col3, #T_ecdca_row10_col4, #T_ecdca_row10_col5, #T_ecdca_row11_col0, #T_ecdca_row11_col1, #T_ecdca_row11_col2, #T_ecdca_row11_col3, #T_ecdca_row11_col4, #T_ecdca_row11_col5, #T_ecdca_row12_col0, #T_ecdca_row12_col1, #T_ecdca_row12_col2, #T_ecdca_row12_col3, #T_ecdca_row12_col4, #T_ecdca_row12_col5, #T_ecdca_row13_col0, #T_ecdca_row13_col1, #T_ecdca_row13_col2, #T_ecdca_row13_col3, #T_ecdca_row13_col4, #T_ecdca_row13_col5, #T_ecdca_row14_col0, #T_ecdca_row14_col1, #T_ecdca_row14_col2, #T_ecdca_row14_col3, #T_ecdca_row14_col4, #T_ecdca_row14_col5, #T_ecdca_row15_col0, #T_ecdca_row15_col1, #T_ecdca_row15_col2, #T_ecdca_row15_col3, #T_ecdca_row15_col4, #T_ecdca_row15_col5, #T_ecdca_row16_col0, #T_ecdca_row16_col1, #T_ecdca_row16_col2, #T_ecdca_row16_col3, #T_ecdca_row16_col4, #T_ecdca_row16_col5, #T_ecdca_row17_col0, #T_ecdca_row17_col1, #T_ecdca_row17_col2, #T_ecdca_row17_col3, #T_ecdca_row17_col4, #T_ecdca_row17_col5, #T_ecdca_row18_col0, #T_ecdca_row18_col1, #T_ecdca_row18_col2, #T_ecdca_row18_col3, #T_ecdca_row18_col4, #T_ecdca_row18_col5, #T_ecdca_row19_col0, #T_ecdca_row19_col1, #T_ecdca_row19_col2, #T_ecdca_row19_col3, #T_ecdca_row19_col4, #T_ecdca_row19_col5, #T_ecdca_row20_col0, #T_ecdca_row20_col1, #T_ecdca_row20_col2, #T_ecdca_row20_col3, #T_ecdca_row20_col4, #T_ecdca_row20_col5, #T_ecdca_row21_col0, #T_ecdca_row21_col1, #T_ecdca_row21_col2, #T_ecdca_row21_col3, #T_ecdca_row21_col4, #T_ecdca_row21_col5, #T_ecdca_row22_col0, #T_ecdca_row22_col1, #T_ecdca_row22_col2, #T_ecdca_row22_col3, #T_ecdca_row22_col4, #T_ecdca_row22_col5, #T_ecdca_row23_col0, #T_ecdca_row23_col1, #T_ecdca_row23_col2, #T_ecdca_row23_col3, #T_ecdca_row23_col4, #T_ecdca_row23_col5 {
#   background-color: #f9f9f9;
#   border-color: black;
#   border-width: 1px;
#   border-style: solid;
#   color: black;
#   font-family: Arial;
#   text-align: center;
# }
# </style>
# <table id="T_ecdca">
#   <caption>Hourly Simulation results</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ecdca_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_ecdca_level0_col1" class="col_heading level0 col1" >Time</th>
#       <th id="T_ecdca_level0_col2" class="col_heading level0 col2" >Load Demand (kW)</th>
#       <th id="T_ecdca_level0_col3" class="col_heading level0 col3" >PV Generation (kW)</th>
#       <th id="T_ecdca_level0_col4" class="col_heading level0 col4" >Wind Generation (kW)</th>
#       <th id="T_ecdca_level0_col5" class="col_heading level0 col5" >Residual Load (kW)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ecdca_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ecdca_row0_col0" class="data row0 col0" >2012-06-01</td>
#       <td id="T_ecdca_row0_col1" class="data row0 col1" >00:00:00</td>
#       <td id="T_ecdca_row0_col2" class="data row0 col2" >1.94</td>
#       <td id="T_ecdca_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_ecdca_row0_col4" class="data row0 col4" >1.08</td>
#       <td id="T_ecdca_row0_col5" class="data row0 col5" >0.86</td>
#     </tr>
#     <tr>
#       <th id="T_ecdca_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ecdca_row1_col0" class="data row1 col0" >2012-06-01</td>
#       <td id="T_ecdca_row1_col1" class="data row1 col1" >01:00:00</td>
#       <td id="T_ecdca_row1_col2" class="data row1 col2" >1.68</td>
#       <td id="T_ecdca_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_ecdca_row1_col4" class="data row1 col4" >0.82</td>
#       <td id="T_ecdca_row1_col5" class="data row1 col5" >0.86</td>
#     </tr>
#     <tr>
#       <th id="T_ecdca_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ecdca_row2_col0" class="data row2 col0" >2012-06-01</td>
#       <td id="T_ecdca_row2_col1" class="data row2 col1" >02:00:00</td>
#       <td id="T_ecdca_row2_col2" class="data row2 col2" >0.86</td>
#       <td id="T_ecdca_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_ecdca_row2_col4" class="data row2 col4" >0.79</td>
#       <td id="T_ecdca_row2_col5" class="data row2 col5" >0.07</td>
#     </tr>
#     <tr>
#       <th id="T_ecdca_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ecdca_row3_col0" class="data row3 col0" >2012-06-01</td>
#       <td id="T_ecdca_row3_col1" class="data row3 col1" >03:00:00</td>
#       <td id="T_ecdca_row3_col2" class="data row3 col2" >0.44</td>
#       <td id="T_ecdca_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_ecdca_row3_col4" class="data row3 col4" >0.78</td>
#       <td id="T_ecdca_row3_col5" class="data row3 col5" >-0.34</td>
#     </tr>
#     <tr>
#       <th id="T_ecdca_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ecdca_row4_col0" class="data row4 col0" >2012-06-01</td>
#       <td id="T_ecdca_row4_col1" class="data row4 col1" >04:00:00</td>
#       <td id="T_ecdca_row4_col2" class="data row4 col2" >0.41</td>
#       <td id="T_ecdca_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_ecdca_row4_col4" class="data row4 col4" >0.35</td>
#       <td id="T_ecdca_row4_col5" class="data row4 col5" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_ecdca_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ecdca_row5_col0" class="data row5 col0" >2012-06-01</td>
#       <td id="T_ecdca_row5_col1" class="data row5 col1" >05:00:00</td>
#       <td id="T_ecdca_row5_col2" class="data row5 col2" >0.64</td>
#       <td id="T_ecdca_row5_col3" class="data row5 col3" >0.21</td>
#       <td id="T_ecdca_row5_col4" class="data row5 col4" >0.39</td>
#       <td id="T_ecdca_row5_col5" class="data row5 col5" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_ecdca_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ecdca_row6_col0" class="data row6 col0" >2012-06-01</td>
#       <td id="T_ecdca_row6_col1" class="data row6 col1" >06:00:00</td>
#       <td id="T_ecdca_row6_col2" class="data row6 col2" >0.92</td>
#       <td id="T_ecdca_row6_col3" class="data row6 col3" >0.43</td>
#       <td id="T_ecdca_row6_col4" class="data row6 col4" >0.59</td>
#       <td id="T_ecdca_row6_col5" class="data row6 col5" >-0.11</td>
#     </tr>
#     <tr>
#       <th id="T_ecdca_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ecdca_row7_col0" class="data row7 col0" >2012-06-01</td>
#       <td id="T_ecdca_row7_col1" class="data row7 col1" >07:00:00</td>
#       <td id="T_ecdca_row7_col2" class="data row7 col2" >0.96</td>
#       <td id="T_ecdca_row7_col3" class="data row7 col3" >0.72</td>
#       <td id="T_ecdca_row7_col4" class="data row7 col4" >0.23</td>
#       <td id="T_ecdca_row7_col5" class="data row7 col5" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_ecdca_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ecdca_row8_col0" class=

# %% [markdown]
# The residents have decided to implement a community storage, to enhance the utilization of their local generation. The electricity generated from the local renewable energy sources is stored in the battery when generation exceeds the local demand. The stored energy is used when the local generation cannot cover the demand.
#
# Thus, the controller connected to the battery acts in the following way: In case of not enough local generation to cover the demand of the neighbourhood electricity is taken from the battery storage if the battery is sufficiently charged. If the battery charge is not enough, electricity is taken from the grid to meet the demand. The storage level of the battery is given by the SOC (State of Charge). The State of Charge of a battery represents the current charge level relative to its full capacity, typically expressed in percentages.  Thus, SOC=100% means the battery is fully charged and SOC=0% means it is fully discharged. To prevent damage the battery has a minimum and maximum SOC (upper and lower boundary) included in the control logic, that cannot be surpassed.

# %% [markdown]
# ![T1_RES_case_Bat](Graphics_T1/neighbourhood_RES_Bat_case_T1.png)

# %% [markdown]
# ### Task 3 Neighbourhood with local RES and Communal Battery
#
# a) Run the following python code that simulates a typical day in the local community with renewable generation and battery storage. For this task the State of charge is 100% in the beginning of the day. How does the residual load curve change compared to task 2 (the utilization of small scale local renewable generation without storage).
#
# b) Change the State of charge parameter to 50% in the beginning of the day and run the simulation again. Explain how this affects the residual load curve.
#
# c): Change the State of charge parameter to 10% in the beginning of the day and run the simulation again. Explain how this affects the residual load curve.

# %%
# %%capture
CONFIG_FILE = 'Tutorial_Power_Balance_b.yaml'
simulation_RES_Bat = Simulation(CONFIG_FILE)
simulation_RES_Bat.set_model_param(model_name='CSVload', parameter='file_path', value='data/load_data.txt')
simulation_RES_Bat.set_model_param(model_name='CSV_pv', parameter='file_path', value='data/pv_data_Rotterdam_NL-15min.txt')
simulation_RES_Bat.set_model_param(model_name='CSV_wind', parameter='file_path', value='data/winddata_NL.txt')



new_settings = {'Wind1': {'p_rated': 0.3}, # power in kW
                'Load1': {'houses': 5}, # number of houses
                'PV1':{'cap': 500}, # installed capacity in W
                'Battery1':{'max_p': 0.8, 'min_p': -0.8,'soc_min': 10, 'soc_max': 90},
                }

simulation_RES_Bat.edit_models(new_settings)

# with this function you can set an initial state of a model such as the soc of the battery
simulation_RES_Bat.set_model_state(model_name='Battery1', state='soc', value=100)

simulation_RES_Bat.set_scenario_param('start_time', '2012-06-01 00:00:00')
simulation_RES_Bat.set_scenario_param('end_time', '2012-06-01 23:45:00')

# run the simulation
simulation_RES_Bat.run()
# Out:
# 2025-06-16 12:11:13.880 | INFO     | mosaik.async_scenario:start:420 - Starting "Collector" as "Collector-0" ...
# 2025-06-16 12:11:15.321 | INFO     | mosaik.async_scenario:start:420 - Starting "Nuclear1" as "Nuclear1-0" ...
# 2025-06-16 12:11:15.321 | WARNING  | mosaik.async_scenario:user_warning:342 - c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\site-packages\mosaik\adapters.py:98: UserWarning: Simulator Nuclear1-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-06-16 12:11:15.326 | INFO     | mosaik.async_scenario:start:420 - Starting "FossilPlant1" as "FossilPlant1-0" ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 24
#      21 simulation_RES_Bat.set_scenario_param('end_time', '2012-06-01 23:45:00')
#      23 # run the simulation
# ---> 24 simulation_RES_Bat.run()
#
# File ~\Documents\Illuminator-BAP-EE-2025\src\illuminator\engine.py:470, in Simulation.run(self)
#     467 monitor = collector.Monitor()
#     469 # Dictionary to keep track of created model entities
# --> 470 model_entities = start_simulators(world, config['models'])
#     472 # Connect the models based on the connections specified in the configuration
#     473 world = build_connections(world, model_entities, connections=config['connections'], models=config['models'])
#
# File ~\Documents\Illuminator-BAP-EE-2025\src\illuminator\engine.py:194, in start_simulators(world, models)
#     185     entity = model_factory.create(num=1)
#     187 else:
#     188     # simulator = world.start(sim_name=model_name,
#     189     #                     # **model_parameters
#    (...)    192     #                     # Some items must be passed here, and some other at create()
#     193     #                     )
# --> 194     simulator = world.start(sim_name=model_name, sim_params={model_name: model})
#     196     # TODO: make all parameters in create() **kwargs
#     197     # TODO: model_type must match model name in META for the simulator
#     198
#     199     # allows instantiating an entity by using the value of 'model_type' dynamically
#     200     model_factory = getattr(simulator, model_type)
#
# File c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\site-packages\mosaik\scenario.py:152, in World.start(self, sim_name, sim_id, **sim_params)
#     142 def start(
#     143     self,
#     144     sim_name: str,
#     145     sim_id: Optional[SimId] = None,
#     146     **sim_params: Any,
#     147 ) -> ModelFactory:
#     148     """
#     149     Start the simulator named *sim_name* and return a
#     150     :class:`ModelFactory` for it.
#     151     """
# --> 152     async_model_factory = self.loop.run_until_complete(
#     153         self._async_world.start(sim_name, sim_id, **sim_params)
#     154     )
#     155     return ModelFactory(async_model_factory, self.loop)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\asyncio\futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\asyncio\tasks.py:277, in Task.__step(***failed resolving arguments***)
#     273 try:
#     274     if exc is None:
#     275         # We use the `send` method directly, because coroutines
#     276         # don't have `__iter__` and `__next__` methods.
# --> 277         result = coro.send(None)
#     278     else:
#     279         result = coro.throw(exc)
#
# File c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\site-packages\mosaik\async_scenario.py:425, in AsyncWorld.start(self, sim_name, sim_id, **sim_params)
#     416     raise ScenarioError(
#     417         f"A simulator with sim_id '{sim_id}' has already been started. "
#     418         "Choose a different sim_id."
#     419     )
#     420 logger.info(
#     421     'Starting "{sim_name}" as "{sim_id}" ...',
#     422     sim_name=sim_name,
#     423     sim_id=sim_id,
#     424 )
# --> 425 proxy = await simmanager.start(
#     426     self, sim_name, sim_id, self.time_resolution, sim_params
#     427 )
#     428 # Create the ModelFactory before the SimRunner as it performs
#     429 # some checks on the simulator's meta.
#     430 model_factory = AsyncModelFactory(self, self.current_group, sim_id, proxy)
#
# File c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\site-packages\mosaik\simmanager.py:134, in start(world, sim_name, sim_id, time_resolution, sim_params)
#     132 for sim_type, starter in starters.items():
#     133     if sim_type in sim_config:
# --> 134         proxy = await starter(
#     135             world.config, sim_name, sim_config, MosaikRemote(world, sim_id)
#     136         )
#     137         try:
#     138             proxy = await asyncio.wait_for(
#     139                 init_and_get_adapter(
#     140                     proxy,
#    (...)    145                 world.config["start_timeout"],
#     146             )
#
# File c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\site-packages\mosaik\simmanager.py:205, in start_inproc(mosaik_config, sim_name, sim_config, mosaik_remote)
#     200     origerr = err.args[0]
#     201     raise ScenarioError(
#     202         'Simulator "%s" could not be started: %s --> %s'
#     203         % (sim_name, details, origerr)
#     204     ) from None
# --> 205 sim = cls()
#     207 if int(mosaik_api_v3.__version__.split(".")[0]) < 3:
#     208     raise ScenarioError("Mosaik 3 requires mosaik_api_v3 or newer.")
#
# File ~\Documents\Illuminator-BAP-EE-2025\src\illuminator\models\Fossil\fossil_model.py:62, in Fossil.__init__(self, **kwargs)
#      60 self.rated_pow = self.parameters['rated_pow']
#      61 self.output_type = self.parameters['output_type']
# ---> 62 self.name = self.parameters['name']
#      63 self.bio_frac = self.parameters['bio_frac']
#      64 self.bio_waste = self.parameters['bio_waste']
#
# KeyError: 'name'

# %%
functions_T1.summarize_results('./out_Tutorial_Power_Balance_b.csv', battery_active = True)
# Out:
# <style type="text/css">
# #T_c54b2_row0_col0, #T_c54b2_row0_col1, #T_c54b2_row0_col2, #T_c54b2_row0_col3, #T_c54b2_row0_col4, #T_c54b2_row0_col5, #T_c54b2_row0_col6, #T_c54b2_row0_col7, #T_c54b2_row0_col8, #T_c54b2_row1_col0, #T_c54b2_row1_col1, #T_c54b2_row1_col2, #T_c54b2_row1_col3, #T_c54b2_row1_col4, #T_c54b2_row1_col5, #T_c54b2_row1_col6, #T_c54b2_row1_col7, #T_c54b2_row1_col8, #T_c54b2_row2_col0, #T_c54b2_row2_col1, #T_c54b2_row2_col2, #T_c54b2_row2_col3, #T_c54b2_row2_col4, #T_c54b2_row2_col5, #T_c54b2_row2_col6, #T_c54b2_row2_col7, #T_c54b2_row2_col8, #T_c54b2_row3_col0, #T_c54b2_row3_col1, #T_c54b2_row3_col2, #T_c54b2_row3_col3, #T_c54b2_row3_col4, #T_c54b2_row3_col5, #T_c54b2_row3_col6, #T_c54b2_row3_col7, #T_c54b2_row3_col8, #T_c54b2_row4_col0, #T_c54b2_row4_col1, #T_c54b2_row4_col2, #T_c54b2_row4_col3, #T_c54b2_row4_col4, #T_c54b2_row4_col5, #T_c54b2_row4_col6, #T_c54b2_row4_col7, #T_c54b2_row4_col8, #T_c54b2_row5_col0, #T_c54b2_row5_col1, #T_c54b2_row5_col2, #T_c54b2_row5_col3, #T_c54b2_row5_col4, #T_c54b2_row5_col5, #T_c54b2_row5_col6, #T_c54b2_row5_col7, #T_c54b2_row5_col8, #T_c54b2_row6_col0, #T_c54b2_row6_col1, #T_c54b2_row6_col2, #T_c54b2_row6_col3, #T_c54b2_row6_col4, #T_c54b2_row6_col5, #T_c54b2_row6_col6, #T_c54b2_row6_col7, #T_c54b2_row6_col8, #T_c54b2_row7_col0, #T_c54b2_row7_col1, #T_c54b2_row7_col2, #T_c54b2_row7_col3, #T_c54b2_row7_col4, #T_c54b2_row7_col5, #T_c54b2_row7_col6, #T_c54b2_row7_col7, #T_c54b2_row7_col8, #T_c54b2_row8_col0, #T_c54b2_row8_col1, #T_c54b2_row8_col2, #T_c54b2_row8_col3, #T_c54b2_row8_col4, #T_c54b2_row8_col5, #T_c54b2_row8_col6, #T_c54b2_row8_col7, #T_c54b2_row8_col8, #T_c54b2_row9_col0, #T_c54b2_row9_col1, #T_c54b2_row9_col2, #T_c54b2_row9_col3, #T_c54b2_row9_col4, #T_c54b2_row9_col5, #T_c54b2_row9_col6, #T_c54b2_row9_col7, #T_c54b2_row9_col8, #T_c54b2_row10_col0, #T_c54b2_row10_col1, #T_c54b2_row10_col2, #T_c54b2_row10_col3, #T_c54b2_row10_col4, #T_c54b2_row10_col5, #T_c54b2_row10_col6, #T_c54b2_row10_col7, #T_c54b2_row10_col8, #T_c54b2_row11_col0, #T_c54b2_row11_col1, #T_c54b2_row11_col2, #T_c54b2_row11_col3, #T_c54b2_row11_col4, #T_c54b2_row11_col5, #T_c54b2_row11_col6, #T_c54b2_row11_col7, #T_c54b2_row11_col8, #T_c54b2_row12_col0, #T_c54b2_row12_col1, #T_c54b2_row12_col2, #T_c54b2_row12_col3, #T_c54b2_row12_col4, #T_c54b2_row12_col5, #T_c54b2_row12_col6, #T_c54b2_row12_col7, #T_c54b2_row12_col8, #T_c54b2_row13_col0, #T_c54b2_row13_col1, #T_c54b2_row13_col2, #T_c54b2_row13_col3, #T_c54b2_row13_col4, #T_c54b2_row13_col5, #T_c54b2_row13_col6, #T_c54b2_row13_col7, #T_c54b2_row13_col8, #T_c54b2_row14_col0, #T_c54b2_row14_col1, #T_c54b2_row14_col2, #T_c54b2_row14_col3, #T_c54b2_row14_col4, #T_c54b2_row14_col5, #T_c54b2_row14_col6, #T_c54b2_row14_col7, #T_c54b2_row14_col8, #T_c54b2_row15_col0, #T_c54b2_row15_col1, #T_c54b2_row15_col2, #T_c54b2_row15_col3, #T_c54b2_row15_col4, #T_c54b2_row15_col5, #T_c54b2_row15_col6, #T_c54b2_row15_col7, #T_c54b2_row15_col8, #T_c54b2_row16_col0, #T_c54b2_row16_col1, #T_c54b2_row16_col2, #T_c54b2_row16_col3, #T_c54b2_row16_col4, #T_c54b2_row16_col5, #T_c54b2_row16_col6, #T_c54b2_row16_col7, #T_c54b2_row16_col8, #T_c54b2_row17_col0, #T_c54b2_row17_col1, #T_c54b2_row17_col2, #T_c54b2_row17_col3, #T_c54b2_row17_col4, #T_c54b2_row17_col5, #T_c54b2_row17_col6, #T_c54b2_row17_col7, #T_c54b2_row17_col8, #T_c54b2_row18_col0, #T_c54b2_row18_col1, #T_c54b2_row18_col2, #T_c54b2_row18_col3, #T_c54b2_row18_col4, #T_c54b2_row18_col5, #T_c54b2_row18_col6, #T_c54b2_row18_col7, #T_c54b2_row18_col8, #T_c54b2_row19_col0, #T_c54b2_row19_col1, #T_c54b2_row19_col2, #T_c54b2_row19_col3, #T_c54b2_row19_col4, #T_c54b2_row19_col5, #T_c54b2_row19_col6, #T_c54b2_row19_col7, #T_c54b2_row19_col8, #T_c54b2_row20_col0, #T_c54b2_row20_col1, #T_c54b2_row20_col2, #T_c54b2_row20_col3, #T_c54b2_row20_col4, #T_c54b2_row20_col5, #T_c54b2_row20_col6, #T_c54b2_row20_col7, #T_c54b2_row20_col8, #T_c54b2_row21_col0, #T_c54b2_row21_col1, #T_c54b2_row21_col2, #T_c54b2_row21_col3, #T_c54b2_row21_col4, #T_c54b2_row21_c ...
#   background-color: #f9f9f9;
#   border-color: black;
#   border-width: 1px;
#   border-style: solid;
#   color: black;
#   font-family: Arial;
#   text-align: center;
# }
# </style>
# <table id="T_c54b2">
#   <caption>Hourly Simulation results</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c54b2_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_c54b2_level0_col1" class="col_heading level0 col1" >Time</th>
#       <th id="T_c54b2_level0_col2" class="col_heading level0 col2" >Load Demand (kW)</th>
#       <th id="T_c54b2_level0_col3" class="col_heading level0 col3" >PV Generation (kW)</th>
#       <th id="T_c54b2_level0_col4" class="col_heading level0 col4" >Wind Generation (kW)</th>
#       <th id="T_c54b2_level0_col5" class="col_heading level0 col5" >Residual Load (kW)</th>
#       <th id="T_c54b2_level0_col6" class="col_heading level0 col6" >Battery SOC (%)</th>
#       <th id="T_c54b2_level0_col7" class="col_heading level0 col7" >Power to Battery (kW)</th>
#       <th id="T_c54b2_level0_col8" class="col_heading level0 col8" >Power to Grid (kW)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c54b2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c54b2_row0_col0" class="data row0 col0" >2012-06-01</td>
#       <td id="T_c54b2_row0_col1" class="data row0 col1" >00:00:00</td>
#       <td id="T_c54b2_row0_col2" class="data row0 col2" >1.94</td>
#       <td id="T_c54b2_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_c54b2_row0_col4" class="data row0 col4" >1.08</td>
#       <td id="T_c54b2_row0_col5" class="data row0 col5" >0.86</td>
#       <td id="T_c54b2_row0_col6" class="data row0 col6" >100</td>
#       <td id="T_c54b2_row0_col7" class="data row0 col7" >-0.86</td>
#       <td id="T_c54b2_row0_col8" class="data row0 col8" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c54b2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c54b2_row1_col0" class="data row1 col0" >2012-06-01</td>
#       <td id="T_c54b2_row1_col1" class="data row1 col1" >01:00:00</td>
#       <td id="T_c54b2_row1_col2" class="data row1 col2" >1.68</td>
#       <td id="T_c54b2_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_c54b2_row1_col4" class="data row1 col4" >0.82</td>
#       <td id="T_c54b2_row1_col5" class="data row1 col5" >0.86</td>
#       <td id="T_c54b2_row1_col6" class="data row1 col6" >70.12</td>
#       <td id="T_c54b2_row1_col7" class="data row1 col7" >-0.86</td>
#       <td id="T_c54b2_row1_col8" class="data row1 col8" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c54b2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c54b2_row2_col0" class="data row2 col0" >2012-06-01</td>
#       <td id="T_c54b2_row2_col1" class="data row2 col1" >02:00:00</td>
#       <td id="T_c54b2_row2_col2" class="data row2 col2" >0.86</td>
#       <td id="T_c54b2_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_c54b2_row2_col4" class="data row2 col4" >0.79</td>
#       <td id="T_c54b2_row2_col5" class="data row2 col5" >0.07</td>
#       <td id="T_c54b2_row2_col6" class="data row2 col6" >40.22</td>
#       <td id="T_c54b2_row2_col7" class="data row2 col7" >-0.07</td>
#       <td id="T_c54b2_row2_col8" class="data row2 col8" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c54b2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c54b2_row3_col0" class="data row3 col0" >2012-06-01</td>
#       <td id="T_c54b2_row3_col1" class="data row3 col1" >03:00:00</td>
#       <td id="T_c54b2_row3_col2" class="data row3 col2" >0.44</td

# %%
functions_T1.summarize_results('./out_Tutorial_Power_Balance_a.csv', battery_active = False)
# Out:
# <style type="text/css">
# #T_a4ca2_row0_col0, #T_a4ca2_row0_col1, #T_a4ca2_row0_col2, #T_a4ca2_row0_col3, #T_a4ca2_row0_col4, #T_a4ca2_row0_col5, #T_a4ca2_row1_col0, #T_a4ca2_row1_col1, #T_a4ca2_row1_col2, #T_a4ca2_row1_col3, #T_a4ca2_row1_col4, #T_a4ca2_row1_col5, #T_a4ca2_row2_col0, #T_a4ca2_row2_col1, #T_a4ca2_row2_col2, #T_a4ca2_row2_col3, #T_a4ca2_row2_col4, #T_a4ca2_row2_col5, #T_a4ca2_row3_col0, #T_a4ca2_row3_col1, #T_a4ca2_row3_col2, #T_a4ca2_row3_col3, #T_a4ca2_row3_col4, #T_a4ca2_row3_col5, #T_a4ca2_row4_col0, #T_a4ca2_row4_col1, #T_a4ca2_row4_col2, #T_a4ca2_row4_col3, #T_a4ca2_row4_col4, #T_a4ca2_row4_col5, #T_a4ca2_row5_col0, #T_a4ca2_row5_col1, #T_a4ca2_row5_col2, #T_a4ca2_row5_col3, #T_a4ca2_row5_col4, #T_a4ca2_row5_col5, #T_a4ca2_row6_col0, #T_a4ca2_row6_col1, #T_a4ca2_row6_col2, #T_a4ca2_row6_col3, #T_a4ca2_row6_col4, #T_a4ca2_row6_col5, #T_a4ca2_row7_col0, #T_a4ca2_row7_col1, #T_a4ca2_row7_col2, #T_a4ca2_row7_col3, #T_a4ca2_row7_col4, #T_a4ca2_row7_col5, #T_a4ca2_row8_col0, #T_a4ca2_row8_col1, #T_a4ca2_row8_col2, #T_a4ca2_row8_col3, #T_a4ca2_row8_col4, #T_a4ca2_row8_col5, #T_a4ca2_row9_col0, #T_a4ca2_row9_col1, #T_a4ca2_row9_col2, #T_a4ca2_row9_col3, #T_a4ca2_row9_col4, #T_a4ca2_row9_col5, #T_a4ca2_row10_col0, #T_a4ca2_row10_col1, #T_a4ca2_row10_col2, #T_a4ca2_row10_col3, #T_a4ca2_row10_col4, #T_a4ca2_row10_col5, #T_a4ca2_row11_col0, #T_a4ca2_row11_col1, #T_a4ca2_row11_col2, #T_a4ca2_row11_col3, #T_a4ca2_row11_col4, #T_a4ca2_row11_col5, #T_a4ca2_row12_col0, #T_a4ca2_row12_col1, #T_a4ca2_row12_col2, #T_a4ca2_row12_col3, #T_a4ca2_row12_col4, #T_a4ca2_row12_col5, #T_a4ca2_row13_col0, #T_a4ca2_row13_col1, #T_a4ca2_row13_col2, #T_a4ca2_row13_col3, #T_a4ca2_row13_col4, #T_a4ca2_row13_col5, #T_a4ca2_row14_col0, #T_a4ca2_row14_col1, #T_a4ca2_row14_col2, #T_a4ca2_row14_col3, #T_a4ca2_row14_col4, #T_a4ca2_row14_col5, #T_a4ca2_row15_col0, #T_a4ca2_row15_col1, #T_a4ca2_row15_col2, #T_a4ca2_row15_col3, #T_a4ca2_row15_col4, #T_a4ca2_row15_col5, #T_a4ca2_row16_col0, #T_a4ca2_row16_col1, #T_a4ca2_row16_col2, #T_a4ca2_row16_col3, #T_a4ca2_row16_col4, #T_a4ca2_row16_col5, #T_a4ca2_row17_col0, #T_a4ca2_row17_col1, #T_a4ca2_row17_col2, #T_a4ca2_row17_col3, #T_a4ca2_row17_col4, #T_a4ca2_row17_col5, #T_a4ca2_row18_col0, #T_a4ca2_row18_col1, #T_a4ca2_row18_col2, #T_a4ca2_row18_col3, #T_a4ca2_row18_col4, #T_a4ca2_row18_col5, #T_a4ca2_row19_col0, #T_a4ca2_row19_col1, #T_a4ca2_row19_col2, #T_a4ca2_row19_col3, #T_a4ca2_row19_col4, #T_a4ca2_row19_col5, #T_a4ca2_row20_col0, #T_a4ca2_row20_col1, #T_a4ca2_row20_col2, #T_a4ca2_row20_col3, #T_a4ca2_row20_col4, #T_a4ca2_row20_col5, #T_a4ca2_row21_col0, #T_a4ca2_row21_col1, #T_a4ca2_row21_col2, #T_a4ca2_row21_col3, #T_a4ca2_row21_col4, #T_a4ca2_row21_col5, #T_a4ca2_row22_col0, #T_a4ca2_row22_col1, #T_a4ca2_row22_col2, #T_a4ca2_row22_col3, #T_a4ca2_row22_col4, #T_a4ca2_row22_col5, #T_a4ca2_row23_col0, #T_a4ca2_row23_col1, #T_a4ca2_row23_col2, #T_a4ca2_row23_col3, #T_a4ca2_row23_col4, #T_a4ca2_row23_col5 {
#   background-color: #f9f9f9;
#   border-color: black;
#   border-width: 1px;
#   border-style: solid;
#   color: black;
#   font-family: Arial;
#   text-align: center;
# }
# </style>
# <table id="T_a4ca2">
#   <caption>Hourly Simulation results</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4ca2_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_a4ca2_level0_col1" class="col_heading level0 col1" >Time</th>
#       <th id="T_a4ca2_level0_col2" class="col_heading level0 col2" >Load Demand (kW)</th>
#       <th id="T_a4ca2_level0_col3" class="col_heading level0 col3" >PV Generation (kW)</th>
#       <th id="T_a4ca2_level0_col4" class="col_heading level0 col4" >Wind Generation (kW)</th>
#       <th id="T_a4ca2_level0_col5" class="col_heading level0 col5" >Residual Load (kW)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4ca2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a4ca2_row0_col0" class="data row0 col0" >2012-06-01</td>
#       <td id="T_a4ca2_row0_col1" class="data row0 col1" >00:00:00</td>
#       <td id="T_a4ca2_row0_col2" class="data row0 col2" >1.94</td>
#       <td id="T_a4ca2_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a4ca2_row0_col4" class="data row0 col4" >1.08</td>
#       <td id="T_a4ca2_row0_col5" class="data row0 col5" >0.86</td>
#     </tr>
#     <tr>
#       <th id="T_a4ca2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a4ca2_row1_col0" class="data row1 col0" >2012-06-01</td>
#       <td id="T_a4ca2_row1_col1" class="data row1 col1" >01:00:00</td>
#       <td id="T_a4ca2_row1_col2" class="data row1 col2" >1.68</td>
#       <td id="T_a4ca2_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_a4ca2_row1_col4" class="data row1 col4" >0.82</td>
#       <td id="T_a4ca2_row1_col5" class="data row1 col5" >0.86</td>
#     </tr>
#     <tr>
#       <th id="T_a4ca2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a4ca2_row2_col0" class="data row2 col0" >2012-06-01</td>
#       <td id="T_a4ca2_row2_col1" class="data row2 col1" >02:00:00</td>
#       <td id="T_a4ca2_row2_col2" class="data row2 col2" >0.86</td>
#       <td id="T_a4ca2_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_a4ca2_row2_col4" class="data row2 col4" >0.79</td>
#       <td id="T_a4ca2_row2_col5" class="data row2 col5" >0.07</td>
#     </tr>
#     <tr>
#       <th id="T_a4ca2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a4ca2_row3_col0" class="data row3 col0" >2012-06-01</td>
#       <td id="T_a4ca2_row3_col1" class="data row3 col1" >03:00:00</td>
#       <td id="T_a4ca2_row3_col2" class="data row3 col2" >0.44</td>
#       <td id="T_a4ca2_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_a4ca2_row3_col4" class="data row3 col4" >0.78</td>
#       <td id="T_a4ca2_row3_col5" class="data row3 col5" >-0.34</td>
#     </tr>
#     <tr>
#       <th id="T_a4ca2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a4ca2_row4_col0" class="data row4 col0" >2012-06-01</td>
#       <td id="T_a4ca2_row4_col1" class="data row4 col1" >04:00:00</td>
#       <td id="T_a4ca2_row4_col2" class="data row4 col2" >0.41</td>
#       <td id="T_a4ca2_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_a4ca2_row4_col4" class="data row4 col4" >0.35</td>
#       <td id="T_a4ca2_row4_col5" class="data row4 col5" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_a4ca2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a4ca2_row5_col0" class="data row5 col0" >2012-06-01</td>
#       <td id="T_a4ca2_row5_col1" class="data row5 col1" >05:00:00</td>
#       <td id="T_a4ca2_row5_col2" class="data row5 col2" >0.64</td>
#       <td id="T_a4ca2_row5_col3" class="data row5 col3" >0.21</td>
#       <td id="T_a4ca2_row5_col4" class="data row5 col4" >0.39</td>
#       <td id="T_a4ca2_row5_col5" class="data row5 col5" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_a4ca2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a4ca2_row6_col0" class="data row6 col0" >2012-06-01</td>
#       <td id="T_a4ca2_row6_col1" class="data row6 col1" >06:00:00</td>
#       <td id="T_a4ca2_row6_col2" class="data row6 col2" >0.92</td>
#       <td id="T_a4ca2_row6_col3" class="data row6 col3" >0.43</td>
#       <td id="T_a4ca2_row6_col4" class="data row6 col4" >0.59</td>
#       <td id="T_a4ca2_row6_col5" class="data row6 col5" >-0.11</td>
#     </tr>
#     <tr>
#       <th id="T_a4ca2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a4ca2_row7_col0" class="data row7 col0" >2012-06-01</td>
#       <td id="T_a4ca2_row7_col1" class="data row7 col1" >07:00:00</td>
#       <td id="T_a4ca2_row7_col2" class="data row7 col2" >0.96</td>
#       <td id="T_a4ca2_row7_col3" class="data row7 col3" >0.72</td>
#       <td id="T_a4ca2_row7_col4" class="data row7 col4" >0.23</td>
#       <td id="T_a4ca2_row7_col5" class="data row7 col5" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_a4ca2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a4ca2_row8_col0" class=

# %% [markdown]
# The residents have decided to implement a community storage, to enhance the utilization of their local generation. The electricity generated from the local renewable energy sources is stored in the battery when generation exceeds the local demand. The stored energy is used when the local generation cannot cover the demand.
#
# Thus, the controller connected to the battery acts in the following way: In case of not enough local generation to cover the demand of the neighbourhood electricity is taken from the battery storage if the battery is sufficiently charged. If the battery charge is not enough, electricity is taken from the grid to meet the demand. The storage level of the battery is given by the SOC (State of Charge). The State of Charge of a battery represents the current charge level relative to its full capacity, typically expressed in percentages.  Thus, SOC=100% means the battery is fully charged and SOC=0% means it is fully discharged. To prevent damage the battery has a minimum and maximum SOC (upper and lower boundary) included in the control logic, that cannot be surpassed.

# %% [markdown]
# ![T1_RES_case_Bat](Graphics_T1/neighbourhood_RES_Bat_case_T1.png)

# %% [markdown]
# ### Task 3 Neighbourhood with local RES and Communal Battery
#
# a) Run the following python code that simulates a typical day in the local community with renewable generation and battery storage. For this task the State of charge is 100% in the beginning of the day. How does the residual load curve change compared to task 2 (the utilization of small scale local renewable generation without storage).
#
# b) Change the State of charge parameter to 50% in the beginning of the day and run the simulation again. Explain how this affects the residual load curve.
#
# c): Change the State of charge parameter to 10% in the beginning of the day and run the simulation again. Explain how this affects the residual load curve.

# %%
# %%capture
CONFIG_FILE = 'Tutorial_Power_Balance_b.yaml'
simulation_RES_Bat = Simulation(CONFIG_FILE)
simulation_RES_Bat.set_model_param(model_name='CSVload', parameter='file_path', value='data/load_data.txt')
simulation_RES_Bat.set_model_param(model_name='CSV_pv', parameter='file_path', value='data/pv_data_Rotterdam_NL-15min.txt')
simulation_RES_Bat.set_model_param(model_name='CSV_wind', parameter='file_path', value='data/winddata_NL.txt')

new_settings = {'Wind1': {'p_rated': 0.3}, # power in kW
                'Load1': {'houses': 5}, # number of houses
                'PV1':{'cap': 500}, # installed capacity in W
                'Battery1':{'max_p': 0.8, 'min_p': -0.8,'soc_min': 10, 'soc_max': 90}, #max_p, min_p in kW
                }


simulation_RES_Bat.edit_models(new_settings)

# with this function you can set an initial state of a model such as the soc of the battery
simulation_RES_Bat.set_model_state(model_name='Battery1', state='soc', value=100)

simulation_RES_Bat.set_scenario_param('start_time', '2012-06-01 00:00:00')
simulation_RES_Bat.set_scenario_param('end_time', '2012-06-01 23:45:00')

# run the simulation
simulation_RES_Bat.run()
# Out:
# 2025-06-16 12:11:17.317 | INFO     | mosaik.async_scenario:start:420 - Starting "Collector" as "Collector-0" ...
# 2025-06-16 12:11:18.564 | INFO     | mosaik.async_scenario:start:420 - Starting "Nuclear1" as "Nuclear1-0" ...
# 2025-06-16 12:11:18.564 | WARNING  | mosaik.async_scenario:user_warning:342 - c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\site-packages\mosaik\adapters.py:98: UserWarning: Simulator Nuclear1-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-06-16 12:11:18.564 | INFO     | mosaik.async_scenario:start:420 - Starting "FossilPlant1" as "FossilPlant1-0" ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 23
#      20 simulation_RES_Bat.set_scenario_param('end_time', '2012-06-01 23:45:00')
#      22 # run the simulation
# ---> 23 simulation_RES_Bat.run()
#
# File ~\Documents\Illuminator-BAP-EE-2025\src\illuminator\engine.py:470, in Simulation.run(self)
#     467 monitor = collector.Monitor()
#     469 # Dictionary to keep track of created model entities
# --> 470 model_entities = start_simulators(world, config['models'])
#     472 # Connect the models based on the connections specified in the configuration
#     473 world = build_connections(world, model_entities, connections=config['connections'], models=config['models'])
#
# File ~\Documents\Illuminator-BAP-EE-2025\src\illuminator\engine.py:194, in start_simulators(world, models)
#     185     entity = model_factory.create(num=1)
#     187 else:
#     188     # simulator = world.start(sim_name=model_name,
#     189     #                     # **model_parameters
#    (...)    192     #                     # Some items must be passed here, and some other at create()
#     193     #                     )
# --> 194     simulator = world.start(sim_name=model_name, sim_params={model_name: model})
#     196     # TODO: make all parameters in create() **kwargs
#     197     # TODO: model_type must match model name in META for the simulator
#     198
#     199     # allows instantiating an entity by using the value of 'model_type' dynamically
#     200     model_factory = getattr(simulator, model_type)
#
# File c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\site-packages\mosaik\scenario.py:152, in World.start(self, sim_name, sim_id, **sim_params)
#     142 def start(
#     143     self,
#     144     sim_name: str,
#     145     sim_id: Optional[SimId] = None,
#     146     **sim_params: Any,
#     147 ) -> ModelFactory:
#     148     """
#     149     Start the simulator named *sim_name* and return a
#     150     :class:`ModelFactory` for it.
#     151     """
# --> 152     async_model_factory = self.loop.run_until_complete(
#     153         self._async_world.start(sim_name, sim_id, **sim_params)
#     154     )
#     155     return ModelFactory(async_model_factory, self.loop)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\asyncio\futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\asyncio\tasks.py:277, in Task.__step(***failed resolving arguments***)
#     273 try:
#     274     if exc is None:
#     275         # We use the `send` method directly, because coroutines
#     276         # don't have `__iter__` and `__next__` methods.
# --> 277         result = coro.send(None)
#     278     else:
#     279         result = coro.throw(exc)
#
# File c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\site-packages\mosaik\async_scenario.py:425, in AsyncWorld.start(self, sim_name, sim_id, **sim_params)
#     416     raise ScenarioError(
#     417         f"A simulator with sim_id '{sim_id}' has already been started. "
#     418         "Choose a different sim_id."
#     419     )
#     420 logger.info(
#     421     'Starting "{sim_name}" as "{sim_id}" ...',
#     422     sim_name=sim_name,
#     423     sim_id=sim_id,
#     424 )
# --> 425 proxy = await simmanager.start(
#     426     self, sim_name, sim_id, self.time_resolution, sim_params
#     427 )
#     428 # Create the ModelFactory before the SimRunner as it performs
#     429 # some checks on the simulator's meta.
#     430 model_factory = AsyncModelFactory(self, self.current_group, sim_id, proxy)
#
# File c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\site-packages\mosaik\simmanager.py:134, in start(world, sim_name, sim_id, time_resolution, sim_params)
#     132 for sim_type, starter in starters.items():
#     133     if sim_type in sim_config:
# --> 134         proxy = await starter(
#     135             world.config, sim_name, sim_config, MosaikRemote(world, sim_id)
#     136         )
#     137         try:
#     138             proxy = await asyncio.wait_for(
#     139                 init_and_get_adapter(
#     140                     proxy,
#    (...)    145                 world.config["start_timeout"],
#     146             )
#
# File c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\site-packages\mosaik\simmanager.py:205, in start_inproc(mosaik_config, sim_name, sim_config, mosaik_remote)
#     200     origerr = err.args[0]
#     201     raise ScenarioError(
#     202         'Simulator "%s" could not be started: %s --> %s'
#     203         % (sim_name, details, origerr)
#     204     ) from None
# --> 205 sim = cls()
#     207 if int(mosaik_api_v3.__version__.split(".")[0]) < 3:
#     208     raise ScenarioError("Mosaik 3 requires mosaik_api_v3 or newer.")
#
# File ~\Documents\Illuminator-BAP-EE-2025\src\illuminator\models\Fossil\fossil_model.py:62, in Fossil.__init__(self, **kwargs)
#      60 self.rated_pow = self.parameters['rated_pow']
#      61 self.output_type = self.parameters['output_type']
# ---> 62 self.name = self.parameters['name']
#      63 self.bio_frac = self.parameters['bio_frac']
#      64 self.bio_waste = self.parameters['bio_waste']
#
# KeyError: 'name'

# %%
functions_T1.summarize_results('./out_Tutorial_Power_Balance_b.csv', battery_active = True)
# Out:
# Task was destroyed but it is pending!
# task: <Task pending name='handle remote requests for ???' coro=<RemoteProxy._handle_remote_requests() running at c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\site-packages\mosaik\proxies.py:181> wait_for=<Future pending cb=[Task.__wakeup()]>>
# Task was destroyed but it is pending!
# task: <Task pending name='Reader task for Collector' coro=<Channel._receive_forever() running at c:\Users\roosb\AppData\Local\Programs\Python\Python311\Lib\site-packages\mosaik_api_v3\connection.py:167> wait_for=<Future pending cb=[Task.__wakeup()]>>
# <style type="text/css">
# #T_e9abf_row0_col0, #T_e9abf_row0_col1, #T_e9abf_row0_col2, #T_e9abf_row0_col3, #T_e9abf_row0_col4, #T_e9abf_row0_col5, #T_e9abf_row0_col6, #T_e9abf_row0_col7, #T_e9abf_row0_col8, #T_e9abf_row1_col0, #T_e9abf_row1_col1, #T_e9abf_row1_col2, #T_e9abf_row1_col3, #T_e9abf_row1_col4, #T_e9abf_row1_col5, #T_e9abf_row1_col6, #T_e9abf_row1_col7, #T_e9abf_row1_col8, #T_e9abf_row2_col0, #T_e9abf_row2_col1, #T_e9abf_row2_col2, #T_e9abf_row2_col3, #T_e9abf_row2_col4, #T_e9abf_row2_col5, #T_e9abf_row2_col6, #T_e9abf_row2_col7, #T_e9abf_row2_col8, #T_e9abf_row3_col0, #T_e9abf_row3_col1, #T_e9abf_row3_col2, #T_e9abf_row3_col3, #T_e9abf_row3_col4, #T_e9abf_row3_col5, #T_e9abf_row3_col6, #T_e9abf_row3_col7, #T_e9abf_row3_col8, #T_e9abf_row4_col0, #T_e9abf_row4_col1, #T_e9abf_row4_col2, #T_e9abf_row4_col3, #T_e9abf_row4_col4, #T_e9abf_row4_col5, #T_e9abf_row4_col6, #T_e9abf_row4_col7, #T_e9abf_row4_col8, #T_e9abf_row5_col0, #T_e9abf_row5_col1, #T_e9abf_row5_col2, #T_e9abf_row5_col3, #T_e9abf_row5_col4, #T_e9abf_row5_col5, #T_e9abf_row5_col6, #T_e9abf_row5_col7, #T_e9abf_row5_col8, #T_e9abf_row6_col0, #T_e9abf_row6_col1, #T_e9abf_row6_col2, #T_e9abf_row6_col3, #T_e9abf_row6_col4, #T_e9abf_row6_col5, #T_e9abf_row6_col6, #T_e9abf_row6_col7, #T_e9abf_row6_col8, #T_e9abf_row7_col0, #T_e9abf_row7_col1, #T_e9abf_row7_col2, #T_e9abf_row7_col3, #T_e9abf_row7_col4, #T_e9abf_row7_col5, #T_e9abf_row7_col6, #T_e9abf_row7_col7, #T_e9abf_row7_col8, #T_e9abf_row8_col0, #T_e9abf_row8_col1, #T_e9abf_row8_col2, #T_e9abf_row8_col3, #T_e9abf_row8_col4, #T_e9abf_row8_col5, #T_e9abf_row8_col6, #T_e9abf_row8_col7, #T_e9abf_row8_col8, #T_e9abf_row9_col0, #T_e9abf_row9_col1, #T_e9abf_row9_col2, #T_e9abf_row9_col3, #T_e9abf_row9_col4, #T_e9abf_row9_col5, #T_e9abf_row9_col6, #T_e9abf_row9_col7, #T_e9abf_row9_col8, #T_e9abf_row10_col0, #T_e9abf_row10_col1, #T_e9abf_row10_col2, #T_e9abf_row10_col3, #T_e9abf_row10_col4, #T_e9abf_row10_col5, #T_e9abf_row10_col6, #T_e9abf_row10_col7, #T_e9abf_row10_col8, #T_e9abf_row11_col0, #T_e9abf_row11_col1, #T_e9abf_row11_col2, #T_e9abf_row11_col3, #T_e9abf_row11_col4, #T_e9abf_row11_col5, #T_e9abf_row11_col6, #T_e9abf_row11_col7, #T_e9abf_row11_col8, #T_e9abf_row12_col0, #T_e9abf_row12_col1, #T_e9abf_row12_col2, #T_e9abf_row12_col3, #T_e9abf_row12_col4, #T_e9abf_row12_col5, #T_e9abf_row12_col6, #T_e9abf_row12_col7, #T_e9abf_row12_col8, #T_e9abf_row13_col0, #T_e9abf_row13_col1, #T_e9abf_row13_col2, #T_e9abf_row13_col3, #T_e9abf_row13_col4, #T_e9abf_row13_col5, #T_e9abf_row13_col6, #T_e9abf_row13_col7, #T_e9abf_row13_col8, #T_e9abf_row14_col0, #T_e9abf_row14_col1, #T_e9abf_row14_col2, #T_e9abf_row14_col3, #T_e9abf_row14_col4, #T_e9abf_row14_col5, #T_e9abf_row14_col6, #T_e9abf_row14_col7, #T_e9abf_row14_col8, #T_e9abf_row15_col0, #T_e9abf_row15_col1, #T_e9abf_row15_col2, #T_e9abf_row15_col3, #T_e9abf_row15_col4, #T_e9abf_row15_col5, #T_e9abf_row15_col6, #T_e9abf_row15_col7, #T_e9abf_row15_col8, #T_e9abf_row16_col0, #T_e9abf_row16_col1, #T_e9abf_row16_col2, #T_e9abf_row16_col3, #T_e9abf_row16_col4, #T_e9abf_row16_col5, #T_e9abf_row16_col6, #T_e9abf_row16_col7, #T_e9abf_row16_col8, #T_e9abf_row17_col0, #T_e9abf_row17_col1, #T_e9abf_row17_col2, #T_e9abf_row17_col3, #T_e9abf_row17_col4, #T_e9abf_row17_col5, #T_e9abf_row17_col6, #T_e9abf_row17_col7, #T_e9abf_row17_col8, #T_e9abf_row18_col0, #T_e9abf_row18_col1, #T_e9abf_row18_col2, #T_e9abf_row18_col3, #T_e9abf_row18_col4, #T_e9abf_row18_col5, #T_e9abf_row18_col6, #T_e9abf_row18_col7, #T_e9abf_row18_col8, #T_e9abf_row19_col0, #T_e9abf_row19_col1, #T_e9abf_row19_col2, #T_e9abf_row19_col3, #T_e9abf_row19_col4, #T_e9abf_row19_col5, #T_e9abf_row19_col6, #T_e9abf_row19_col7, #T_e9abf_row19_col8, #T_e9abf_row20_col0, #T_e9abf_row20_col1, #T_e9abf_row20_col2, #T_e9abf_row20_col3, #T_e9abf_row20_col4, #T_e9abf_row20_col5, #T_e9abf_row20_col6, #T_e9abf_row20_col7, #T_e9abf_row20_col8, #T_e9abf_row21_col0, #T_e9abf_row21_col1, #T_e9abf_row21_col2, #T_e9abf_row21_col3, #T_e9abf_row21_col4, #T_e9abf_row21_c ...
#   background-color: #f9f9f9;
#   border-color: black;
#   border-width: 1px;
#   border-style: solid;
#   color: black;
#   font-family: Arial;
#   text-align: center;
# }
# </style>
# <table id="T_e9abf">
#   <caption>Hourly Simulation results</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9abf_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_e9abf_level0_col1" class="col_heading level0 col1" >Time</th>
#       <th id="T_e9abf_level0_col2" class="col_heading level0 col2" >Load Demand (kW)</th>
#       <th id="T_e9abf_level0_col3" class="col_heading level0 col3" >PV Generation (kW)</th>
#       <th id="T_e9abf_level0_col4" class="col_heading level0 col4" >Wind Generation (kW)</th>
#       <th id="T_e9abf_level0_col5" class="col_heading level0 col5" >Residual Load (kW)</th>
#       <th id="T_e9abf_level0_col6" class="col_heading level0 col6" >Battery SOC (%)</th>
#       <th id="T_e9abf_level0_col7" class="col_heading level0 col7" >Power to Battery (kW)</th>
#       <th id="T_e9abf_level0_col8" class="col_heading level0 col8" >Power to Grid (kW)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9abf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e9abf_row0_col0" class="data row0 col0" >2012-06-01</td>
#       <td id="T_e9abf_row0_col1" class="data row0 col1" >00:00:00</td>
#       <td id="T_e9abf_row0_col2" class="data row0 col2" >1.94</td>
#       <td id="T_e9abf_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e9abf_row0_col4" class="data row0 col4" >1.08</td>
#       <td id="T_e9abf_row0_col5" class="data row0 col5" >0.86</td>
#       <td id="T_e9abf_row0_col6" class="data row0 col6" >100</td>
#       <td id="T_e9abf_row0_col7" class="data row0 col7" >-0.86</td>
#       <td id="T_e9abf_row0_col8" class="data row0 col8" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e9abf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e9abf_row1_col0" class="data row1 col0" >2012-06-01</td>
#       <td id="T_e9abf_row1_col1" class="data row1 col1" >01:00:00</td>
#       <td id="T_e9abf_row1_col2" class="data row1 col2" >1.68</td>
#       <td id="T_e9abf_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_e9abf_row1_col4" class="data row1 col4" >0.82</td>
#       <td id="T_e9abf_row1_col5" class="data row1 col5" >0.86</td>
#       <td id="T_e9abf_row1_col6" class="data row1 col6" >70.12</td>
#       <td id="T_e9abf_row1_col7" class="data row1 col7" >-0.86</td>
#       <td id="T_e9abf_row1_col8" class="data row1 col8" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e9abf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e9abf_row2_col0" class="data row2 col0" >2012-06-01</td>
#       <td id="T_e9abf_row2_col1" class="data row2 col1" >02:00:00</td>
#       <td id="T_e9abf_row2_col2" class="data row2 col2" >0.86</td>
#       <td id="T_e9abf_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_e9abf_row2_col4" class="data row2 col4" >0.79</td>
#       <td id="T_e9abf_row2_col5" class="data row2 col5" >0.07</td>
#       <td id="T_e9abf_row2_col6" class="data row2 col6" >40.22</td>
#       <td id="T_e9abf_row2_col7" class="data row2 col7" >-0.07</td>
#       <td id="T_e9abf_row2_col8" class="data row2 col8" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e9abf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e9abf_row3_col0" class="data row3 col0" >2012-06-01</td>
#       <td id="T_e9abf_row3_col1" class="data row3 col1" >03:00:00</td>
#       <td id="T_e9abf_row3_col2" class="data row3 col2" >0.44</td
